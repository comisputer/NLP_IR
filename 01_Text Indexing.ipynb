# %%
"""
name        : Jung In-seok
student ID  : 20131699
major       : Intergrative Engineering_Digital Imaging
date        : March 16, 2019 
"""

# %%
"""
Text Indexing Homework

1) Choose 10 movie scripts from https://www.imsdb.com/
(I suggest to make them in TXT files.)

2) Write a code for indexing the texts,
and draw charts for showing the word distributions of them. 

* You can use one of programming language (Python, Java, and C).
"""

# %%
"""
Reference :
[1] 어절단위로 끊어서 출력하기:
http://word.snu.ac.kr/wiki/doku.php?id=python:tutorial:learn_by_example:word_list

[2] 파이썬을 이용해 파일에서 단어 빈도 계산하기:
https://code.tutsplus.com/ko/tutorials/counting-word-frequency-in-a-file-using-python--cms-25965

[3] 파이썬 딕셔너리 정렬하기:
https://m.blog.naver.com/PostView.nhn?blogId=moonsoo5522&logNo=220826171626&proxyReferer=https%3A%2F%2Fwww.google.com%2F

[4] matplotlib 이용하여 그래프 그리기:
https://ordo.tistory.com/68
"""

# %%
import matplotlib.pyplot as plt
import operator
import re

# %%
movie_idx = 5
movie_list = ["BEAUTY AND THE BEAST",   \
              "COCO",                   \
              "FROZEN",                 \
              "GET OUT",                \
              "LA LA LAND",             \
              "MULAN",                  \
              "SHREK",                  \
              "THE AVENGERS",           \
              "THOR RAGNAROK",          \
              "WALL-E"]

filename = "data/" + movie_list[movie_idx] + ".txt"
file = open(filename, 'r')

# %%
index_list = []

# [1]
for line in file:
    for word in line.split():
        index_list.append(word)

# %%
# [2]
frequency = {}
for word in index_list:
    count = frequency.get(word, 0)
    frequency[word] = count + 1

#frequency_list = frequency.keys()
#for words in frequency_list:
#    print(words, frequency[words])

# %%
# [3]
sortedArr = sorted(frequency.items(), key=operator.itemgetter(1), reverse=True)
print(sortedArr)
# Out:
# [('the', 981), ('and', 531), ('to', 500), ('a', 295), ('of', 262), ('Mulan', 247), ('her', 184), ('his', 177), ('on', 170), ('in', 161), ('I', 147), ('with', 137), ('up', 119), ('Fa', 110), ('you', 103), ('Shang', 98), ('out', 97), ('from', 92), ('at', 92), ('Mushu', 90), ('[Mulan', 87), ('as', 81), ('down', 71), ('is', 69), ('it', 69), ('Chi', 68), ('your', 65), ('into', 64), ('back', 64), ('The', 62), ('for', 61), ('looks', 59), ('him', 54), ('Mushu:', 53), ('Shan-Yu', 52), ('my', 52), ('by', 51), ('Hun', 50), ('Yao', 50), ('Mulan:', 49), ('all', 48), ('Ling', 48), ('off', 47), ('[Cut', 46), ('have', 45), ('that', 44), ('she', 44), ('Chien-Po', 44), ('She', 43), ('Fu', 43), ('this', 42), ('walks', 42), ('Cri-Kee', 42), ('You', 42), ('over', 40), ('sword', 40), ("Mulan's", 39), ('are', 39), ('be', 38), ('Khan', 38), ('around', 37), ('look', 37), ('Zhou', 36), ('will', 35), ('he', 34), ('sees', 33), ('can', 33), ('head', 32), ('through', 32), ('like', 32), ('takes', 32), ('Man', 31), ('then', 31), ('me', 31), ('away', 31), ('runs', 30), ('He', 30), ('Emperor', 30), ('toward', 30), ('grabs', 30), ('Ancestor', 30), ('[Shang', 30), ('Li', 29), ('troops', 29), ('see', 29), ('Shang:', 29), ('get', 28), ("I'm", 28), ('behind', 28), ('And', 27), ('[to', 26), ('just', 25), ('[Mushu', 25), ('what', 24), ('Mulan.', 22), ('we', 22), ('Yao,', 22), ('top', 21), ('one', 21), ('so', 21), ('not', 21), ('Grandma', 21), ('their', 20), ('right', 20), ('[The', 20), ('turns', 20), ('hand', 20), ('do', 20), ('First', 20), ('was', 19), ('towards', 19), ('A', 19), ('onto', 19), ('falls', 19), ('face', 19), ("don't", 19), ('front', 18), ('Bald', 18), ('fire', 18), ('Fu:', 18), ('her.', 18), ('go', 18), ('Great', 17), ('looking', 17), ('causing', 17), ('an', 17), ('girl', 17), ('starts', 17), ('them', 17), ('throws', 16), ('General', 16), ('man', 16), ('arm', 16), ('me.', 16), ('who', 16), ('Mulan]', 16), ('Ling,', 16), ('while', 15), ("Shan-Yu's", 15), ('comes', 15), ('Now', 15), ('take', 15), ('before', 15), ('[calling', 15), ('us', 15), ('bring', 15), ('Mulan]:', 15), ('Who', 15), ('fall', 15), ('Matchmaker', 15), ('Imperial', 15), ('know', 15), ("you're", 14), ('our', 14), ('Little', 14), ('steps', 14), ('But', 14), ('other', 14), ('water', 14), ('near', 14), ("Shang's", 14), ('when', 13), ('walking', 13), ('helmet', 13), ('watches', 13), ('Li:', 13), ('run', 13), ('ground', 13), ('they', 13), ('eyes', 13), ('jumps', 13), ('honor', 13), ('make', 13), ('We', 13), ('about', 13), ('am', 13), ("I'll", 13), ('They', 13), ('ground.', 13), ('#1', 12), ('recruits', 12), ('Zhou:', 12), ('[Fa', 12), ("I've", 12), ('[Cri-Kee', 12), ('side', 12), ('gonna', 12), ('With', 12), ('[looking', 12), ('think', 12), ("it's", 12), ('you?', 12), ('never', 12), ('Stone', 12), ('gets', 12), ('family.', 12), ('sword.', 12), ('uses', 12), ('(Be', 12), ('man)', 12), ('lands', 11), ('holding', 11), ('help', 11), ('begins', 11), ('family', 11), ('pulls', 11), ('Mulan,', 11), ('good', 11), ('must', 11), ('puts', 11), ('hands', 11), ('What', 11), ('Hey,', 11), ('My', 11), ('Oh,', 11), ('[Yao', 11), ('arrow', 11), ('cannon', 11), ('snow', 11), ('could', 10), ('falcon', 10), ('large', 10), ('edge', 10), ("We're", 10), ('under', 10), ('soldiers', 10), ('Your', 10), ('Huns', 10), ('but', 10), ('here', 10), ('Cri-Kee]', 10), ('would', 10), ('if', 10), ('[grabbing', 10), ('hair', 10), ('great', 10), ('All', 10), ('show', 10), ('[with', 10), ('outside', 10), ('above', 10), ("You're", 10), ('next', 10), ('Shan-Yu.', 10), ('#2', 10), ('[Shan-Yu', 10), ('where', 10), ('him.', 9), ('picks', 9), ('left', 9), ('Emperor:', 9), ('Dresser', 9), ('doll', 9), ('high', 9), ('father', 9), ('standing', 9), ('mouth', 9), ('men', 9), ('time', 9), ('rides', 9), ("That's", 9), ('people', 9), ('come', 9), ('Chirp.', 9), ('close', 9), ('[from', 9), ('Yao:', 9), ('worth', 9), ('tent.', 9), ('hits', 8), ('pole', 8), ('him]', 8), ('No', 8), ("Fu's", 8), ('palace', 8), ('conscription', 8), ('bark,', 8), ('shou ...

# %%
# [4]
x = []
y = []
for arr in sortedArr:
    x.append(arr[0])
    y.append(arr[1])

plt.plot(x, y)
plt.xlabel('ID of terms')
plt.ylabel('frequency')

plt.title(movie_list[movie_idx])
plt.show()
