# %%
"""
name        : Jung In-seok
student ID  : 20131699
major       : Intergrative Engineering_Digital Imaging
date        : March 16, 2019 
"""
# Out:
# '\nname        : Jung In-seok\nstudent ID  : 20131699\nmajor       : Intergrative Engineering_Digital Imaging\ndate        : March 16, 2019 \n'

# %%
"""
Text Indexing Homework

1) Choose 10 movie scripts from https://www.imsdb.com/
(I suggest to make them in TXT files.)

2) Write a code for indexing the texts,
and draw charts for showing the word distributions of them. 

* You can use one of programming language (Python, Java, and C).
"""
# Out:
# '\nText Indexing Homework\n\n1) Choose 10 movie scripts from https://www.imsdb.com/\n(I suggest to make them in TXT files.)\n\n2) Write a code for indexing the texts,\nand draw charts for showing the word distributions of them. \n\n* You can use one of programming language (Python, Java, and C).\n'

# %%
"""
Reference :
[1] 어절단위로 끊어서 출력하기:
http://word.snu.ac.kr/wiki/doku.php?id=python:tutorial:learn_by_example:word_list

[2] 파이썬을 이용해 파일에서 단어 빈도 계산하기:
https://code.tutsplus.com/ko/tutorials/counting-word-frequency-in-a-file-using-python--cms-25965

[3] 파이썬 딕셔너리 정렬하기:
https://m.blog.naver.com/PostView.nhn?blogId=moonsoo5522&logNo=220826171626&proxyReferer=https%3A%2F%2Fwww.google.com%2F

[4] matplotlib 이용하여 그래프 그리기:
https://ordo.tistory.com/68
"""
# Out:
# '\nReference :\n[1] 어절단위로 끊어서 출력하기:\nhttp://word.snu.ac.kr/wiki/doku.php?id=python:tutorial:learn_by_example:word_list\n\n[2] 파이썬을 이용해 파일에서 단어 빈도 계산하기:\nhttps://code.tutsplus.com/ko/tutorials/counting-word-frequency-in-a-file-using-python--cms-25965\n\n[3] 파이썬 딕셔너리 정렬하기:\nhttps://m.blog.naver.com/PostView.nhn?blogId=moonsoo5522&logNo=220826171626&proxyReferer=https%3A%2F%2Fwww.google.com%2F\n\n[4] matplotlib 이용하여 그래프 그리기:\nhttps://ordo.tistory.com/68\n'

# %%
import matplotlib.pyplot as plt
import operator
import re

# %%
movie_idx = 9
movie_list = ["BEAUTY AND THE BEAST",   \
              "COCO",                   \
              "FROZEN",                 \
              "GET OUT",                \
              "LA LA LAND",             \
              "MULAN",                  \
              "SHREK",                  \
              "THE AVENGERS",           \
              "THOR RAGNAROK",          \
              "WALL-E"]

filename = "data/" + movie_list[movie_idx] + ".txt"
file = open(filename, 'r')

# %%
index_list = []

# [1]
for line in file:
    for word in line.split():
        index_list.append(word)

# %%
# [2]
frequency = {}
for word in index_list:
    count = frequency.get(word, 0)
    frequency[word] = count + 1

#frequency_list = frequency.keys()
#for words in frequency_list:
#    print(words, frequency[words])

# %%
# [3]
sortedArr = sorted(frequency.items(), key=operator.itemgetter(1), reverse=True)
print(sortedArr)
# Out:
# [('the', 889), ('to', 381), ('The', 283), ('a', 280), ('Wall-E', 275), ('of', 229), ('his', 222), ('in', 205), ('on', 180), ('Eve', 164), ('is', 124), ('A', 120), ('and', 113), ('her', 109), ('out', 101), ('WALL-E', 99), ('ON', 91), ('CAPTAIN', 91), ('at', 88), ('up', 87), ('EVE', 85), ('-', 84), ('into', 83), ('for', 82), ('She', 82), ('He', 77), ('from', 76), ('it', 75), ('with', 69), ('OF', 66), ('back', 62), ('Captain', 59), ('him.', 59), ('over', 58), ('THE', 52), ('M-O', 52), ('Auto', 52), ("Wall-E's", 47), ('all', 43), ('down', 43), ('It', 43), ('up.', 40), ('INT.', 39), ('They', 38), ('off', 38), ('their', 38), ('Wall-E.', 38), ('--', 37), ('an', 35), ('her.', 35), ('it.', 34), ('him', 34), ('Eve.', 34), ('as', 33), ('EXT.', 32), ('COMPUTER', 32), ('through', 31), ('looks', 31), ('plant', 31), ("SHIP'S", 31), ('by', 30), ('you', 29), ('AUTOPILOT', 29), ('like', 28), ('...and', 28), ('are', 26), ('them.', 25), ('plant.', 24), ('one', 23), ('(beeps)', 23), ('I', 23), ('His', 22), ('BRIDGE', 22), ('its', 21), ('(V.O.)', 21), ('behind', 21), ("Eve's", 21), ('Gopher', 21), ('front', 20), ('BNL', 20), ('...The', 20), ('BACK', 20), ('he', 19), ('No', 19), ("It's", 19), ('that', 19), ('MARY', 19), ('Captain.', 19), ('your', 18), ('passengers', 18), ('hover', 18), ('around', 18), ('floor.', 18), ('DECK', 18), ('turns', 17), ('CEO', 17), ('other', 17), ('still', 17), ('head', 17), ('All', 17), ('flies', 17), ('watches', 17), ('has', 17), ('eyes', 16), ('go', 16), ('now', 16), ('TRUCK', 16), ('screen.', 16), ('cockroach', 16), ("WALL-E'S", 16), ('hand', 16), ('Scans', 16), ('get', 16), ('JOHN', 16), ('Wall-E!', 16), ('AXIOM', 16), ('hands', 15), ('out.', 15), ('just', 15), ('onto', 15), ('gun', 15), ('them', 15), ('towards', 14), ('takes', 14), ('open', 14), ('chest', 14), ('chest.', 14), ('N', 14), ('off.', 14), ('across', 14), ('be', 14), ('after', 14), ('An', 14), ('rises', 14), ('ship.', 14), ('holds', 14), ('holding', 14), ('doors', 14), ('You', 14), ('console.', 14), ('see', 13), ('TRASH', 13), ('trash', 13), ('LARGE', 13), ('space.', 13), ('between', 13), ('reaches', 13), ("Doesn't", 13), ('head.', 13), ('ship', 13), ('Her', 13), ('hand.', 13), ('down.', 13), ('light', 13), ('have', 13), ('me', 13), ('ROBOT', 12), ('CLOSE', 12), ('past', 12), ('each', 12), ('no', 12), ('opens', 12), ('what', 12), ('face.', 12), ('look', 12), ('hovers', 12), ('DAY', 12), ('scans', 12), ("ship's", 12), ('against', 12), ('begins', 12), ('way', 12), ('next', 12), ('POV', 12), ('chair', 12), ('INSIDE', 12), ("CAPTAIN'S", 12), ('trash.', 11), ('stops', 11), ('back.', 11), ('life.', 11), ('appears', 11), ('shuts', 11), ('under', 11), ('above', 11), ('tries', 11), ('again.', 11), ('right', 11), ('she', 11), ('Wall-E...', 11), ('going', 11), ('Grabs', 11), ('transport', 11), ('time', 11), ('know', 11), ('Lido', 11), ('LIDO', 11), ('room.', 11), ('AUTO', 11), ('&', 10), ('CONTINUOUS', 10), ('we', 10), ('come', 10), ('take', 10), ('away.', 10), ('can', 10), ('BUY', 10), ('side.', 10), ('Pulls', 10), ('Looks', 10), ('button.', 10), ('door.', 10), ('in.', 10), ('away', 10), ('...A', 10), ('moves', 10), ('...a', 10), ('suddenly', 10), ('Just', 10), ('Still', 10), ("He's", 10), ('gives', 10), ('stares', 10), ('Then', 10), ('IN', 10), ('steward', 10), ('PASSENGER', 10), ("can't", 10), ('John', 10), ('QUARTERS', 10), ('We', 10), ("Captain's", 10), ('Rejects', 10), ('GIANT', 9), ('empty', 9), ('new', 9), ('Holds', 9), ('hands.', 9), ('NIGHT', 9), ('LIGHT', 9), ('drops', 9), ('RED', 9), ('along', 9), ('lowers', 9), ('slowly', 9), ('not', 9), ('hatch', 9), ('do', 9), ('TO', 9), ('first', 9), ('this', 9), ('monorail', 9), ('Mary', 9), ('if', 9), ("That's", 9), ('Earth.', 9), ('chute.', 9), ('entire', 8), ('distance.', 8), ('sky.', 8), ('button', 8), ('SAME', 8), ('every', 8), ('remains', 8), ('LATER', 8), ('plays', 8), ('go.', 8), ('PLANT', 8), ('ground.', 8), ('BAY', 8), ('Makes', 8), ('box.', 8), ('robots', 8), ('...the', 8), ('Ee-vah!', 8), ('Ee-vah?', 8),  ...

# %%
# [4]
x = []
y = []
for arr in sortedArr:
    x.append(arr[0])
    y.append(arr[1])

plt.plot(x, y)
plt.xlabel('ID of terms')
plt.ylabel('frequency')

plt.title(movie_list[movie_idx])
plt.show()
